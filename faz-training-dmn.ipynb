# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (100).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (78).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (64).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (59).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (80).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (33).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (48).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (16).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (53).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (82).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (2).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (83).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (99).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (67).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (107).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (15).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (20).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (106).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (98).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (92).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (28).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (81).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (37).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (28).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (53).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (81).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (60).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (6).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (1).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (57).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (29).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (74).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (4).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (19).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (71).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (74).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (41).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (54).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (72).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (90).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (45).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (13).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (107).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (86).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (36).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (80).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (40).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (82).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (99).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (43).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (58).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (44).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (59).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (25).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (96).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (65).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (88).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (7).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (79).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (88).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (30).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (46).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (75).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (56).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (79).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (105).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (63).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (62).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (66).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (68).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (11).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (33).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (57).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (25).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (38).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (17).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (41).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (75).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (73).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (98).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (13).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (89).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (11).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (55).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (63).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (47).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (77).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (8).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (50).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (15).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (106).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (109).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (9).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (104).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (41).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (31).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (56).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (39).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (1).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (75).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (94).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (45).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (23).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (17).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (12).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (66).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (12).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (37).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (30).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (74).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (24).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (72).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (54).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (84).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (2).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (104).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (70).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (84).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (86).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (34).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (13).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (34).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (67).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (42).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (62).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (28).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (40).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (16).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (87).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (42).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (35).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (33).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (97).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (32).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (61).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (86).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (102).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (80).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (62).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (25).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (102).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (82).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (84).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (60).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (27).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (47).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (43).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (85).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (92).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (37).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (76).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (27).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (22).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (55).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (49).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (3).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (97).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (50).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (26).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (90).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (46).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (52).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (77).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (72).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (87).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (22).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (15).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (47).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (69).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (32).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (29).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (78).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (55).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (105).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (48).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (49).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (1).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (38).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (76).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (91).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (68).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (14).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (67).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (8).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (77).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (91).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (73).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (57).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (108).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (64).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (39).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (8).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (46).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (19).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (79).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (5).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (29).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (6).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (30).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (18).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (64).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (3).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (73).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (23).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (3).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (48).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (10).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (49).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (12).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (69).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (20).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (36).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (51).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (103).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (83).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (45).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (9).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (27).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (5).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (68).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (87).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (11).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (43).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (81).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (85).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (7).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (40).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (95).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (94).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (20).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (54).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (35).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (85).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (18).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (70).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (7).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (10).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (88).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (101).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (61).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (4).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (23).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (101).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (39).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (61).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (18).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (2).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (70).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (51).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (24).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (16).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (4).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (22).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (78).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (51).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (14).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (24).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (83).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (21).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (21).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (35).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (95).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (93).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (65).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (60).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (10).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (56).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (58).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (71).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (100).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (93).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (6).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (38).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (5).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (89).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (66).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (36).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (58).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (65).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (19).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (34).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (71).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (44).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (69).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (26).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (63).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (42).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (17).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (59).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (31).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (26).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (32).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (52).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (50).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (103).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (31).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Myopia_clear (96).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (21).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (53).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (44).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (9).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (76).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Normal_clear (14).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (52).jpg
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (55)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (97)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (53)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (42)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (39)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (98)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (72)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (60)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (30)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (58)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (74)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (50)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (29)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (29)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (10)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (61)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (8)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (7)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (77)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (27)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (55)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (25)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (17)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (78)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (17)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (85)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (83)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (105)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (18)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (57)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (17)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (79)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (36)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (24)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (66)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (19)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (44)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (28)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (49)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (69)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (43)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (31)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (36)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (63)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (95)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (59)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (27)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (21)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (38)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (37)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (76)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (47)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (20)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (83)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (40)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (88)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (3)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (82)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (37)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (96)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (78)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (60)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (33)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (86)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (10)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (84)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (76)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (89)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (60)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (100)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (22)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (105)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (52)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (67)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (26)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (86)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (104)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (4)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (42)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (39)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (3)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (65)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (70)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (7)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (50)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (9)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (81)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (39)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (92)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (103)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (34)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (94)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (69)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (54)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (66)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (63)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (24)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (87)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (83)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (5)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (59)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (23)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (69)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (2)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (50)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (95)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (70)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (13)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (2)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (1)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (102)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (20)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (33)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (56)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (81)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (14)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (19)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (35)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (25)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (16)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (41)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (98)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (79)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (66)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (46)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (8)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (5)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (51)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (93)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (48)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (106)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (72)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (23)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (53)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (22)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (26)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (32)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (102)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (11)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (28)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (45)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (100)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (4)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (76)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (49)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (38)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (94)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (107)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (62)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (12)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (91)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (68)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (64)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (85)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (77)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (32)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (44)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (89)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (84)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (12)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (56)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (73)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (20)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (81)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (87)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (74)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (107)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (29)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (10)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (24)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (91)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (3)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (9)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (1)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (59)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (74)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (40)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (64)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (109)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (84)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (1)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (80)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (23)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (68)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (52)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (6)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (15)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (106)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (41)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (27)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (90)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (13)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (37)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (79)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (6)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (75)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (103)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (108)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (42)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (104)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (55)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (48)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (35)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (19)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (57)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (45)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (44)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (36)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (77)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (43)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (70)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (73)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (61)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (82)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (58)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (52)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (80)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (34)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (34)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (47)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (48)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (58)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (51)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (47)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (5)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (8)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (33)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (16)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (88)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (26)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (75)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (80)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (21)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (73)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (18)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (101)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (11)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (14)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (18)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (62)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (67)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (101)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (43)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (49)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (63)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (12)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (38)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (99)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (25)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (46)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (78)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (32)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (41)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (99)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (2)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (56)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (85)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (54)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (6)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (4)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (88)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (87)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (71)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (31)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (22)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (15)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (31)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (72)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (82)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (13)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (97)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (51)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (28)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (11)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (53)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (67)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (93)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (54)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (40)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (68)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (61)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (71)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (16)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (64)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (86)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (45)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (75)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (90)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (92)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (65)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (9)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (57)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (35)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (71)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (21)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (65)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (30)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (7)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (62)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (15)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (46)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Normal_clear (30)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Diabetic_clear (96)_mask.png
# /kaggle/input/faz-training2/faz-training-data/pre-processed_masks/Myopia_clear (14)_mask.png

# %%
import os
import torch
import numpy as np
from torch.utils.data import Dataset
from PIL import Image
import albumentations as A
from albumentations.pytorch import ToTensorV2

# %%
image_dir="/kaggle/input/faz-training2/faz-training-data/pre-processed_images"
mask_dir="/kaggle/input/faz-training2/faz-training-data/pre-processed_masks"

# %%
class FAZDataset (Dataset):
    def __init__(self, image_dir, mask_dir, transform=None):
        self.image_dir=image_dir
        self.mask_dir=mask_dir
        self.transform=transform
        self.images=sorted(os.listdir(image_dir))
    def __len__(self):
        return len(self.images)
    def __getitem__(self,idx):
        img_path=os.path.join(self.image_dir, self.images[idx])
        mask_name=self.images[idx].replace(".jpg", "_mask.png")
        mask_path=os.path.join(self.mask_dir, mask_name)
        image=np.array(Image.open(img_path).convert("RGB"))
        mask=np.array(Image.open(mask_path).convert("L"), dtype=np.float32)
        mask=mask/255.0
        if self.transform:
            augmented=self.transform(image=image, mask=mask)
            image=augmented['image']
            mask=augmented['mask'].unsqueeze(0)
        return image, mask

# %%
train_transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5), 
    A.Resize(256,256),
    
    A.RandomRotate90(p=0.6),

    A.ShiftScaleRotate(
        shift_limit=0.05, scale_limit=0.05, rotate_limit=15, 
        border_mode=0, p=0.5
    ),

    A.OneOf([
        A.RandomBrightnessContrast(brightness_limit=0.1, contrast_limit=0.1),
        A.CLAHE(clip_limit=2.0),
        A.GaussianBlur(blur_limit=3)
    ], p=0.3), 

    A.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),

   A.ElasticTransform(alpha=1, sigma=50, alpha_affine=50, p=0.2),

    ToTensorV2()
])
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /tmp/ipykernel_115/2166533050.py:21: UserWarning: Argument(s) 'alpha_affine' are not valid for transform ElasticTransform
#   A.ElasticTransform(alpha=1, sigma=50, alpha_affine=50, p=0.2),

# %%
from torch.utils.data import DataLoader

# 2. Create dataset instance
train_dataset = FAZDataset(
    image_dir="/kaggle/input/faz-training2/faz-training-data/pre-processed_images",
    mask_dir="/kaggle/input/faz-training2/faz-training-data/pre-processed_masks",
    transform=train_transform
)

# 3. Load into DataLoader
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)

# %%
dataset = FAZDataset(image_dir, mask_dir, transform=train_transform)

# %%
import random
import matplotlib.pyplot as plt
image_dir = "/kaggle/input/faz-training2/faz-training-data/pre-processed_images"
mask_dir = "/kaggle/input/faz-training2/faz-training-data/pre-processed_masks"


# Pick N random samples from your dataset
sample_indices = random.sample(range(len(os.listdir(image_dir))), 8)

plt.figure(figsize=(15, 6))
for i, idx in enumerate(sample_indices):
    
    image_name = os.listdir(image_dir)[idx]
    image_path = os.path.join(image_dir, image_name)
    mask_name = image_name.replace(".jpg", "_mask.png")
    mask_path = os.path.join(mask_dir, mask_name)

    
    image = np.array(Image.open(image_path).convert("RGB"))
    mask = np.array(Image.open(mask_path).convert("L"))

    
    augmented = train_transform(image=image, mask=mask)
    aug_img = augmented["image"].permute(1, 2, 0).numpy()
    aug_mask = augmented["mask"].squeeze().numpy()

    
    plt.subplot(2, len(sample_indices), i+1)
    plt.imshow(aug_img, cmap='gray')
    plt.title("Augmented Image")
    plt.axis('off')

    plt.subplot(2, len(sample_indices), i+1+len(sample_indices))
    plt.imshow(aug_mask, cmap='gray')
    plt.title("Augmented Mask")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
import torch.nn as nn

# %%
# !pip install -q segmentation-models-pytorch
import segmentation_models_pytorch as smp

# %%
from torchvision import models

# %%
#denseNet121 as encoder
class DenseEncoder(nn.Module):
    def __init__(self):
        super(DenseEncoder, self).__init__()
        densenet = models.densenet121(pretrained=True)

       
        self.initial = densenet.features[0]          
        self.pool = densenet.features[1]             
        self.dense_block1 = densenet.features[2]     
        self.trans1 = densenet.features[3]           
        self.dense_block2 = densenet.features[4]     
        self.trans2 = densenet.features[5]           
        self.dense_block3 = densenet.features[6]      
        self.trans3 = densenet.features[7]            
        self.dense_block4 = densenet.features[8]      
        self.norm5 = densenet.features[9]             

    def forward(self, x):
        x0 = self.initial(x)         
        x1 = self.pool(x0)           
        x2 = self.dense_block1(x1)   
        x3 = self.trans1(x2)         
        x4 = self.dense_block2(x3)   
        x5 = self.trans2(x4)         
        x6 = self.dense_block3(x5)   
        x7 = self.trans3(x6)         
        x8 = self.dense_block4(x7)   
        x9 = self.norm5(x8)          

        return [x0, x2, x4, x6, x9]

# %%
import matplotlib.pyplot as plt
import torchvision.transforms as T
from PIL import Image

# 1. Load an image and preprocess
image_path = "/kaggle/input/faz-training2/faz-training-data/pre-processed_images/Diabetic_clear (1).jpg"

# Apply same preprocessing used during training
transform = T.Compose([
    T.Resize((400, 400)),
    T.ToTensor()
])

img = Image.open(image_path).convert("RGB")
img_tensor = transform(img).unsqueeze(0)  # Shape: [1, 3, H, W]

# 2. Pass image through encoder
encoder = DenseEncoder()
encoder.eval()
with torch.no_grad():
    features = encoder(img_tensor)

# 3. Visualize a few channels from each output stage
def visualize_feature_map(feature_map, title, channels=[0, 5, 10]):
    plt.figure(figsize=(15, 4))
    for i, ch in enumerate(channels):
        plt.subplot(1, len(channels), i+1)
        plt.imshow(feature_map[0, ch].cpu(), cmap='viridis')
        plt.title(f"{title} | Channel {ch}")
        plt.axis('off')
    plt.show()

# Loop over selected encoder outputs
layer_names = ['x0', 'x2', 'x4', 'x6', 'x9']
for name, fmap in zip(layer_names, features):
    visualize_feature_map(fmap, title=name)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
import torch.nn.functional as F

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# -------------------------
# ASPP Block
# -------------------------
class ASPP(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=1)
        self.conv2 = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=6, dilation=6)
        self.conv3 = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=12, dilation=12)
        self.conv4 = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=18, dilation=18)

        self.global_pool = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Conv2d(in_channels, out_channels, kernel_size=1),
            nn.ReLU(inplace=True)
        )

        self.final = nn.Sequential(
            nn.Conv2d(out_channels * 5, out_channels, kernel_size=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        x1 = self.conv1(x)
        x2 = self.conv2(x)
        x3 = self.conv3(x)
        x4 = self.conv4(x)

        x5 = self.global_pool(x)
        x5 = F.interpolate(x5, size=x.shape[2:], mode='bilinear', align_corners=False)

        x_cat = torch.cat([x1, x2, x3, x4, x5], dim=1)
        return self.final(x_cat)

# %%
from torchvision.models import densenet121

class FAZUNet(nn.Module):
    def __init__(self):
        super().__init__()

        # Load DenseNet-121 pretrained backbone
        backbone = densenet121(pretrained=True).features

        self.encoder = backbone
        self.e1 = nn.Sequential(backbone.conv0, backbone.norm0, backbone.relu0)   # 64
        self.e2 = nn.Sequential(backbone.pool0, backbone.denseblock1)             # 256
        self.e3 = nn.Sequential(backbone.transition1, backbone.denseblock2)       # 512
        self.e4 = nn.Sequential(backbone.transition2, backbone.denseblock3)       # 1024
        self.e5 = nn.Sequential(backbone.transition3, backbone.denseblock4)       # 1024

        # ASPP or bottleneck
        self.aspp = nn.Sequential(
            nn.Conv2d(1024, 512, kernel_size=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
        )

        # Decoder blocks
        self.decoder4 = DecoderBlock(512, 1024, 256)
        self.decoder3 = DecoderBlock(256, 512, 128)
        self.decoder2 = DecoderBlock(128, 256, 64)
        self.decoder1 = DecoderBlock(64, 64, 32)

        self.final_conv = nn.Conv2d(32, 1, kernel_size=1)

    def forward(self, x):
        # Encoder
        e1 = self.e1(x)  # 64x128x128
        e2 = self.e2(e1) # 256x64x64
        e3 = self.e3(e2) # 512x32x32
        e4 = self.e4(e3) # 1024x16x16
        e5 = self.e5(e4) # 1024x8x8

        b = self.aspp(e5)  # 512x8x8

        # Decoder
        d4 = self.decoder4(b, e4)  # 256x16x16
        d3 = self.decoder3(d4, e3) # 128x32x32
        d2 = self.decoder2(d3, e2) # 64x64x64
        d1 = self.decoder1(d2, e1) # 32x128x128

        out = F.interpolate(d1, scale_factor=2, mode="bilinear", align_corners=True)  # 32x256x256
        out = self.final_conv(out)  # 1x256x256
        return out

# %%
class SCSEBlock(nn.Module):
    def __init__(self, in_channels):
        super(SCSEBlock, self).__init__()

        # Channel Squeeze and Excitation
        self.cSE = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),             # Global avg pool
            nn.Conv2d(in_channels, in_channels // 2, kernel_size=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels // 2, in_channels, kernel_size=1),
            nn.Sigmoid()
        )

        # Spatial Squeeze and Excitation
        self.sSE = nn.Sequential(
            nn.Conv2d(in_channels, 1, kernel_size=1),
            nn.Sigmoid()
        )

    def forward(self, x):
        cse_out = self.cSE(x) * x
        sse_out = self.sSE(x) * x
        return cse_out + sse_out

# %%
import torch.nn.functional as F

class DecoderBlock(nn.Module):
    def __init__(self, in_channels, skip_channels, out_channels):
        super().__init__()
        self.upsample = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels + skip_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
        )

    def forward(self, x, skip):
        x = self.upsample(x)
        if skip is not None:
            x = torch.cat([x, skip], dim=1)
        return self.conv(x)

# %%
class UNetDecoder(nn.Module):
    def __init__(self, encoder_channels, decoder_channels):
        super(UNetDecoder, self).__init__()

        # We'll build 4 decoder blocks (excluding enc0, which is the original input size)
        self.blocks = nn.ModuleList([
            DecoderBlock(encoder_channels[4], encoder_channels[3], decoder_channels[0]),
            DecoderBlock(decoder_channels[0], encoder_channels[2], decoder_channels[1]),
            DecoderBlock(decoder_channels[1], encoder_channels[1], decoder_channels[2]),
            DecoderBlock(decoder_channels[2], encoder_channels[0], decoder_channels[3]),
        ])

    def forward(self, enc_features):
        x = enc_features[-1]  # Start from the deepest encoder output (enc4)

        for i, block in enumerate(self.blocks):
            skip = enc_features[3 - i] if i < len(enc_features) - 1 else None
            x = block(x, skip)

        return x  # final decoder output

# %%
class SegmentationHead(nn.Module):
    def __init__(self, in_channels, out_channels=1, kernel_size=3):
        super(SegmentationHead, self).__init__()
        self.conv = nn.Conv2d(
            in_channels, out_channels, kernel_size=kernel_size, padding=kernel_size // 2
        )

    def forward(self, x):
        return self.conv(x)

# %%
class DiceLoss(nn.Module):
    def __init__(self, smooth=1.):
        super(DiceLoss, self).__init__()
        self.smooth = smooth

    def forward(self, logits, targets):
        logits = torch.sigmoid(logits)  # since we use BCEWithLogits
        logits = logits.view(-1)
        targets = targets.view(-1)

        intersection = (logits * targets).sum()
        dice = (2. * intersection + self.smooth) / (logits.sum() + targets.sum() + self.smooth)
        return 1 - dice  # Dice Loss

# %%
bce_loss = nn.BCEWithLogitsLoss()
dice_loss = DiceLoss()

def combined_loss(logits, targets):
    return bce_loss(logits, targets) + dice_loss(logits, targets)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import torch.optim as optim
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = FAZUNet().to(device)

optimizer = optim.Adam(model.parameters(), lr=1e-4)

# %%
def dice_score(logits, targets, threshold=0.5):
    probs = torch.sigmoid(logits)
    preds = (probs > threshold).float()
    
    intersection = (preds * targets).sum()
    return (2. * intersection) / (preds.sum() + targets.sum() + 1e-8)

# %%
import torch.nn as nn

# Dice Loss implementation
def dice_loss(pred, target, smooth=1e-5):
    pred = pred.contiguous()
    target = target.contiguous()
    
    intersection = (pred * target).sum(dim=(2,3))
    union = pred.sum(dim=(2,3)) + target.sum(dim=(2,3))

    dice = (2. * intersection + smooth) / (union + smooth)
    return 1 - dice.mean()

# Combined BCE + Dice Loss
class BCEDiceLoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.bce = nn.BCEWithLogitsLoss()  # expects raw logits

    def forward(self, logits, targets):
        bce = self.bce(logits, targets)
        probs = torch.sigmoid(logits)
        d_loss = dice_loss(probs, targets)
        return bce + d_loss

# %%
from torch.utils.data import DataLoader

# Paths to your preprocessed images and masks
image_dir = "/kaggle/input/faz-training2/faz-training-data/pre-processed_images"

mask_dir = "/kaggle/input/faz-training2/faz-training-data/pre-processed_masks"

# Dataset instance
dataset = FAZDataset(image_dir, mask_dir, transform=train_transform)

# DataLoader
loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Get one batch
batch = next(iter(loader))
images, masks = batch  # shapes: [B, 3, H, W], [B, 1, H, W]

# %%
# 1. Create DataLoader
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)

# 2. Get a batch
images, masks = next(iter(train_loader))

print("✅ Batch shapes:")
print("Images:", images.shape)  # [B, 3, H, W]
print("Masks:", masks.shape)    # [B, 1, H, W]
# Out:
# ✅ Batch shapes:
# Images: torch.Size([4, 3, 256, 256])
# Masks: torch.Size([4, 1, 256, 256])

# %%
# Move to device
images = images.to(device)
masks = masks.to(device)

# Forward pass
outputs = model(images)

# Calculate individual losses
bce = bce_loss(outputs, masks)
dice = dice_loss(outputs, masks)
total_loss = bce + dice  # (You can add shape loss later)

print(f"🔍 BCE Loss:  {bce.item():.4f}")
print(f"🔍 Dice Loss: {dice.item():.4f}")
print(f"✅ Total Loss: {total_loss.item():.4f}")
# Out:
# 🔍 BCE Loss:  0.7303
# 🔍 Dice Loss: 0.9835
# ✅ Total Loss: 1.7139

# %%
import matplotlib.pyplot as plt

# Take 1st sample in the batch
pred_mask = outputs[0][0].detach().cpu().numpy()
true_mask = masks[0][0].cpu().numpy()

plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.title("🔹 Ground Truth")
plt.imshow(true_mask, cmap='gray')
plt.subplot(1,2,2)
plt.title("🔸 Predicted")
plt.imshow(pred_mask > 0.5, cmap='gray')  # Thresholded
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128313 (\N{SMALL BLUE DIAMOND}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128312 (\N{SMALL ORANGE DIAMOND}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Create train dataset & loader
train_dataset = FAZDataset(image_dir, mask_dir, transform=train_transform)
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)

# Optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-2)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.5, patience=3, verbose=True
)

torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

# Loss function
loss_fn = BCEDiceLoss()

# Move model to device
model = model.to(device)

# %%
from sklearn.metrics import jaccard_score

# Dice score for binary segmentation
def dice_score(preds, targets, threshold=0.5):
    preds = (preds > threshold).float()
    intersection = (preds * targets).sum()
    return (2. * intersection) / (preds.sum() + targets.sum() + 1e-8)

# %%
from tqdm import tqdm

def train_one_epoch(model, loader, optimizer, loss_fn, device):
    model.train()
    epoch_loss = 0

    for images, masks in tqdm(loader):
        images, masks = images.to(device), masks.to(device)

        optimizer.zero_grad()
        outputs = model(images)

        loss = loss_fn(outputs, masks)
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()

    return epoch_loss / len(loader)

# %%
from sklearn.model_selection import KFold

def get_kfold_loaders(dataset, k=5, batch_size=4):
    kf = KFold(n_splits=k, shuffle=True, random_state=42)
    splits = list(kf.split(dataset))
    for fold, (train_idx, val_idx) in enumerate(splits):
        print(f"\n Fold {fold+1}")
        train_subset = torch.utils.data.Subset(dataset, train_idx)
        val_subset = torch.utils.data.Subset(dataset, val_idx)

        train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
        val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)

        yield fold, train_loader, val_loader

# %%
class EarlyStopping:
    def __init__(self, patience=5, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = float('inf')
        self.early_stop = False

    def __call__(self, val_loss):
        if val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# %%
def train_one_fold(fold, train_loader, val_loader, model, optimizer, loss_fn, device, epochs=25):
    early_stopping = EarlyStopping(patience=5)
    best_model = None

    for epoch in range(epochs):
        model.train()
        train_loss = 0

        for images, masks in train_loader:
            images, masks = images.to(device), masks.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = loss_fn(outputs, masks)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

       

        # Validation
        model.eval()
        val_loss = 0
        dice_total = 0

        with torch.no_grad():
            for images, masks in val_loader:
                images, masks = images.to(device), masks.to(device)
                outputs = model(images)
                loss = loss_fn(outputs, masks)
                val_loss += loss.item()
                dice_total += dice_score(outputs, masks)

        avg_train_loss = train_loss / len(train_loader)
        avg_val_loss = val_loss / len(val_loader)
        avg_dice = dice_total / len(val_loader)
        scheduler.step(avg_val_loss)


        print(f" Epoch {epoch+1}: Train Loss = {avg_train_loss:.4f}, Val Loss = {avg_val_loss:.4f}, Dice = {avg_dice:.4f}")

        if avg_val_loss < early_stopping.best_loss:
            best_model = model.state_dict()

        early_stopping(avg_val_loss)
        if early_stopping.early_stop:
            print("Early stopping")
            break

    model.load_state_dict(best_model)
    return model

# %%
from torch import optim

for fold, train_loader, val_loader in get_kfold_loaders(dataset, k=5):
    model = smp.Unet(encoder_name="densenet121", encoder_weights="imagenet", in_channels=3, classes=1).to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-4)
    loss_fn = BCEDiceLoss()

    trained_model = train_one_fold(fold, train_loader, val_loader, model, optimizer, loss_fn, device)
    torch.save(trained_model.state_dict(), f"unet_faz_fold{fold+1}.pth")
# Out:
#  Fold 1
# config.json:   0%|          | 0.00/156 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/32.3M [00:00<?, ?B/s]
#  Epoch 1: Train Loss = 1.4325, Val Loss = 1.3081, Dice = 0.7092
#  Epoch 2: Train Loss = 1.1734, Val Loss = 1.1184, Dice = 0.7517
#  Epoch 3: Train Loss = 1.0519, Val Loss = 1.0139, Dice = 0.8030
#  Epoch 4: Train Loss = 0.9692, Val Loss = 0.9437, Dice = 0.7578
#  Epoch 5: Train Loss = 0.8920, Val Loss = 0.8520, Dice = 0.8333
#  Epoch 6: Train Loss = 0.8013, Val Loss = 0.7597, Dice = 0.8304
#  Epoch 7: Train Loss = 0.6965, Val Loss = 0.6611, Dice = 0.8199
#  Epoch 8: Train Loss = 0.5884, Val Loss = 0.5577, Dice = 0.8311
#  Epoch 9: Train Loss = 0.4922, Val Loss = 0.4805, Dice = 0.8003
#  Epoch 10: Train Loss = 0.4118, Val Loss = 0.3993, Dice = 0.8353
#  Epoch 11: Train Loss = 0.3472, Val Loss = 0.3611, Dice = 0.8236
#  Epoch 12: Train Loss = 0.3116, Val Loss = 0.3303, Dice = 0.8263
#  Epoch 13: Train Loss = 0.2685, Val Loss = 0.2933, Dice = 0.8317
#  Epoch 14: Train Loss = 0.2365, Val Loss = 0.2643, Dice = 0.8428
#  Epoch 15: Train Loss = 0.2168, Val Loss = 0.2615, Dice = 0.8379
#  Epoch 16: Train Loss = 0.2034, Val Loss = 0.2528, Dice = 0.8289
#  Epoch 17: Train Loss = 0.1962, Val Loss = 0.2297, Dice = 0.8468
#  Epoch 18: Train Loss = 0.1850, Val Loss = 0.2196, Dice = 0.8464
#  Epoch 19: Train Loss = 0.1764, Val Loss = 0.2222, Dice = 0.8416
#  Epoch 20: Train Loss = 0.1718, Val Loss = 0.2131, Dice = 0.8395
#  Epoch 21: Train Loss = 0.1676, Val Loss = 0.2172, Dice = 0.8358
#  Epoch 22: Train Loss = 0.1634, Val Loss = 0.2183, Dice = 0.8304
#  Epoch 23: Train Loss = 0.1542, Val Loss = 0.2071, Dice = 0.8440
#  Epoch 24: Train Loss = 0.1526, Val Loss = 0.2019, Dice = 0.8447
#  Epoch 25: Train Loss = 0.1553, Val Loss = 0.2405, Dice = 0.8131
#
#  Fold 2
#  Epoch 1: Train Loss = 1.3689, Val Loss = 1.2163, Dice = 0.7489
#  Epoch 2: Train Loss = 1.1063, Val Loss = 1.0308, Dice = 0.8194
#  Epoch 3: Train Loss = 0.9676, Val Loss = 0.9298, Dice = 0.8451
#  Epoch 4: Train Loss = 0.8699, Val Loss = 0.8389, Dice = 0.8207
#  Epoch 5: Train Loss = 0.7776, Val Loss = 0.7504, Dice = 0.8174
#  Epoch 6: Train Loss = 0.6876, Val Loss = 0.6574, Dice = 0.8377
#  Epoch 7: Train Loss = 0.5938, Val Loss = 0.5752, Dice = 0.8452
#  Epoch 8: Train Loss = 0.5169, Val Loss = 0.4847, Dice = 0.8535
#  Epoch 9: Train Loss = 0.4344, Val Loss = 0.4306, Dice = 0.8257
#  Epoch 10: Train Loss = 0.3768, Val Loss = 0.3706, Dice = 0.8517
#  Epoch 11: Train Loss = 0.3364, Val Loss = 0.3262, Dice = 0.8548
#  Epoch 12: Train Loss = 0.3006, Val Loss = 0.2857, Dice = 0.8661
#  Epoch 13: Train Loss = 0.2641, Val Loss = 0.2624, Dice = 0.8670
#  Epoch 14: Train Loss = 0.2420, Val Loss = 0.2465, Dice = 0.8626
#  Epoch 15: Train Loss = 0.2258, Val Loss = 0.2357, Dice = 0.8609
#  Epoch 16: Train Loss = 0.2115, Val Loss = 0.2145, Dice = 0.8706
#  Epoch 17: Train Loss = 0.1923, Val Loss = 0.2006, Dice = 0.8700
#  Epoch 18: Train Loss = 0.1811, Val Loss = 0.2176, Dice = 0.8532
#  Epoch 19: Train Loss = 0.1792, Val Loss = 0.2069, Dice = 0.8616
#  Epoch 20: Train Loss = 0.1735, Val Loss = 0.1847, Dice = 0.8701
#  Epoch 21: Train Loss = 0.1672, Val Loss = 0.1800, Dice = 0.8724
#  Epoch 22: Train Loss = 0.1628, Val Loss = 0.2133, Dice = 0.8427
#  Epoch 23: Train Loss = 0.1587, Val Loss = 0.1703, Dice = 0.8748
#  Epoch 24: Train Loss = 0.1477, Val Loss = 0.1738, Dice = 0.8687
#  Epoch 25: Train Loss = 0.1502, Val Loss = 0.1657, Dice = 0.8757
#
#  Fold 3
#  Epoch 1: Train Loss = 1.2991, Val Loss = 1.1421, Dice = 0.7326
#  Epoch 2: Train Loss = 1.0314, Val Loss = 0.9204, Dice = 0.8345
#  Epoch 3: Train Loss = 0.8918, Val Loss = 0.8423, Dice = 0.8227
#  Epoch 4: Train Loss = 0.8066, Val Loss = 0.7514, Dice = 0.8532
#  Epoch 5: Train Loss = 0.7186, Val Loss = 0.6649, Dice = 0.8662
#  Epoch 6: Train Loss = 0.6299, Val Loss = 0.5700, Dice = 0.8633
#  Epoch 7: Train Loss = 0.5469, Val Loss = 0.5002, Dice = 0.8410
#  Epoch 8: Train Loss = 0.4584, Val Loss = 0.4163, Dice = 0.8767
#  Epoch 9: Train Loss = 0.3897, Val Loss = 0.3413, Dice = 0.8809
#  Epoch 10: Train Loss = 0.3324, Val Loss = 0.2868, Dice = 0.8878
#  Epoch 11: Train Loss = 0.2968, Val Loss = 0.2574, Dice = 0.8866
#  Epoch 12: Train Loss = 0.2645, Val Loss = 0.2350, Dice = 0.8868
#  Epoch 13: Train Loss = 0.2426, Val Loss = 0.2296, Dice = 0.8553
#  Epoch 14: Train Loss = 0.2307, Val Loss = 0.1973, Dice = 0.8886
#  Epoch 15: Train Loss = 0.2084, Val Loss = 0.1804, Dice = 0.8953
#  Epoch 16: Train Loss = 0.1992, Val Loss = 0.1772, Dice = 0.8912
#  Epoch 17: Train Loss = 0.1911, Val Loss = 0.1672, Dice = 0.8963
#  Epoch 18: Train Loss = 0.1822, Val Loss = 0.1620, Dice = 0.8958
#  Epoch 19: Train Loss = 0.1777, Val Loss = 0.1580, Dice = 0.8945
#  Epoch 20: Train Loss = 0.1727, Val Loss = 0.1527, Dice = 0.8951
#  Epoch 21: Train Loss = 0.1659, Val Loss = 0.1474, Dice = 0.8961
#  Epoch 22: Train Loss = 0.1641, Val Loss = 0.1443, Dice = 0.8973
#  Epoch 23: Train Loss = 0.1590, Val Loss = 0.1462, Dice = 0.8948
#  Epoch 24: Train Loss = 0.1534, Val Loss = 0.1386, Dice = 0.8976
#  Epoch 25: Train Loss = 0.1562, Val Loss = 0.1397, Dice = 0.8968
#
#  Fold 4
#  Epoch 1: Train Loss = 1.3987, Val Loss = 1.2210, Dice = 0.6832
#  Epoch 2: Train Loss = 1.1059, Val Loss = 1.0388, Dice = 0.8324
#  Epoch 3: Train Loss = 0.9830, Val Loss = 0.9463, Dice = 0.8329
#  Epoch 4: Train Loss = 0.8932, Val Loss = 0.8659, Dice = 0.7866
#  Epoch 5: Train Loss = 0.8067, Val Loss = 0.7728, Dice = 0.8500
#  Epoch 6: Train Loss = 0.7144, Val Loss = 0.6747, Dice = 0.8477
#  Epoch 7: Train Loss = 0.6252, Val Loss = 0.5937, Dice = 0.8397
#  Epoch 8: Train Loss = 0.5370, Val Loss = 0.5098, Dice = 0.8442
#  Epoch 9: Train Loss = 0.4589, Val Loss = 0.4533, Dice = 0.8375
#  Epoch 10: Train Loss = 0.4000, Val Loss = 0.3771, Dice = 0.8633
#  Epoch 11: Train Loss = 0.3437, Val Loss = 0.3087, Dice = 0.8785
#  Epoch 12: Train Loss = 0.2983, Val Loss = 0.2833, Dice = 0.8748
#  Epoch 13: Train Loss = 0.2649, Val Loss = 0.2464, Dice = 0.8824
#  Epoch 14: Train Loss = 0.2385, Val Loss = 0.2292, Dice = 0.8756
#  Epoch 15: Train Loss = 0.2221, Val Loss = 0.2115, Dice = 0.8802
#  Epoch 16: Train Loss = 0.2107, Val Loss = 0.2270, Dice = 0.8535
#  Epoch 17: Train Loss = 0.1962, Val Loss = 0.2085, Dice = 0.8636
#  Epoch 18: Train Loss = 0.1905, Val Loss = 0.2158, Dice = 0.8493
#  Epoch 19: Train Loss = 0.1967, Val Loss = 0.1938, Dice = 0.8761
#  Epoch 20: Train Loss = 0.1803, Val Loss = 0.1834, Dice = 0.8776
#  Epoch 21: Train Loss = 0.1753, Val Loss = 0.1705, Dice = 0.8853
#  Epoch 22: Train Loss = 0.1730, Val Loss = 0.1681, Dice = 0.8807
#  Epoch 23: Train Loss = 0.1643, Val Loss = 0.1721, Dice = 0.8710
#  Epoch 24: Train Loss = 0.1615, Val Loss = 0.1716, Dice = 0.8701
#  Epoch 25: Train Loss = 0.1574, Val Loss = 0.1924, Dice = 0.8617
#
#  Fold 5
#  Epoch 1: Train Loss = 1.8764, Val Loss = 1.6396, Dice = 0.5830
#  Epoch 2: Train Loss = 1.5214, Val Loss = 1.4702, Dice = 0.6730
#  Epoch 3: Train Loss = 1.3644, Val Loss = 1.3256, Dice = 0.7277
#  Epoch 4: Train Loss = 1.2786, Val Loss = 1.2394, Dice = 0.8105
#  Epoch 5: Train Loss = 1.2161, Val Loss = 1.1868, Dice = 0.7857
#  Epoch 6: Train Loss = 1.1566, Val Loss = 1.1241, Dice = 0.8341
#  Epoch 7: Train Loss = 1.1030, Val Loss = 1.0754, Dice = 0.8236
#  Epoch 8: Train Loss = 1.0555, Val Loss = 1.0245, Dice = 0.8494
#  Epoch 9: Train Loss = 1.0075, Val Loss = 0.9794, Dice = 0.8448
#  Epoch 10: Train Loss = 0.9567, Val Loss = 0.9357, Dice = 0.8014
#  Epoch 11: Train Loss = 0.9065, Val Loss = 0.8753, Dice = 0.8365
#  Epoch 12: Train Loss = 0.8562, Val Loss = 0.8276, Dice = 0.8443
#  Epoch 13: Train Loss = 0.8044, Val Loss = 0.7674, Dice = 0.8268
#  Epoch 14: Train Loss = 0.7493, Val Loss = 0.7430, Dice = 0.7995
#  Epoch 15: Train Loss = 0.6933, Val Loss = 0.6226, Dice = 0.8551
#  Epoch 16: Train Loss = 0.6343, Val Loss = 0.6570, Dice = 0.8220
#  Epoch 17: Train Loss = 0.5785, Val Loss = 0.5347, Dice = 0.8487
#  Epoch 18: Train Loss = 0.5173, Val Loss = 0.4530, Dice = 0.8470
#  Epoch 19: Train Loss = 0.4599, Val Loss = 0.4464, Dice = 0.8492
#  Epoch 20: Train Loss = 0.4086, Val Loss = 0.3388, Dice = 0.8659
#  Epoch 21: Train Loss = 0.3583, Val Loss = 0.3524, Dice = 0.8624
#  Epoch 22: Train Loss = 0.3216, Val Loss = 0.2882, Dice = 0.8587
#  Epoch 23: Train Loss = 0.3101, Val Loss = 0.3108, Dice = 0.8383
#  Epoch 24: Train Loss = 0.2767, Val Loss = 0.2514, Dice = 0.8672
#  Epoch 25: Train Loss = 0.2501, Val Loss = 0.2719, Dice = 0.8519
