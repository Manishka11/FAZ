# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (100).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (78).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (64).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (59).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (80).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (33).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (48).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (16).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (53).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (82).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (2).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (83).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (99).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (67).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (107).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (15).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (20).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (106).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (98).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (92).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (28).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (81).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (37).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (28).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (53).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (81).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (60).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (6).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (1).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (57).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (29).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (74).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (4).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (19).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (71).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (74).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (41).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (54).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (72).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (90).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (45).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (13).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (107).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (86).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (36).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (80).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (40).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (82).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (99).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (43).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (58).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (44).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (59).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (25).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (96).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (65).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (88).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (7).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (79).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (88).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (30).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (46).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (75).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (56).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (79).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (105).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (63).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (62).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (66).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (68).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (11).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (33).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (57).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (25).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (38).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (17).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (41).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (75).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (73).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (98).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (13).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (89).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (11).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (55).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (63).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (47).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (77).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (8).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (50).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (15).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (106).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (109).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (9).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (104).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (41).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (31).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (56).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (39).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (1).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (75).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (94).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (45).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (23).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (17).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (12).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (66).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (12).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (37).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (30).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (74).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (24).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (72).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (54).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (84).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (2).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (104).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (70).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (84).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (86).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (34).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (13).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (34).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (67).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (42).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (62).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (28).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (40).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (16).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (87).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (42).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (35).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (33).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (97).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (32).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (61).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (86).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (102).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (80).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (62).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (25).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (102).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (82).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (84).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (60).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (27).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (47).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (43).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (85).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (92).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (37).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (76).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (27).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (22).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (55).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (49).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (3).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (97).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (50).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (26).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (90).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (46).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (52).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (77).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (72).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (87).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (22).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (15).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (47).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (69).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (32).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (29).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (78).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (55).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (105).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (48).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (49).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (1).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (38).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (76).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (91).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (68).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (14).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (67).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (8).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (77).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (91).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (73).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (57).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (108).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (64).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (39).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (8).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (46).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (19).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (79).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (5).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (29).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (6).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (30).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (18).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (64).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (3).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (73).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (23).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (3).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (48).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (10).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (49).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (12).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (69).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (20).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (36).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (51).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (103).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (83).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (45).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (9).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (27).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (5).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (68).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (87).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (11).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (43).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (81).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (85).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (7).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (40).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (95).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (94).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (20).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (54).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (35).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (85).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (18).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (70).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (7).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (10).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (88).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (101).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (61).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (4).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (23).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (101).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (39).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (61).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (18).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (2).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (70).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (51).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (24).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (16).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (4).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (22).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (78).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (51).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (14).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (24).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (83).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (21).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (21).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (35).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (95).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (93).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (65).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (60).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (10).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (56).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (58).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (71).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (100).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (93).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (6).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (38).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (5).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (89).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (66).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (36).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (58).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (65).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (19).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (34).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (71).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (44).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (69).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (26).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (63).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (42).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (17).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (59).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (31).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (26).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (32).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (52).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (50).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (103).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (31).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Myopia_clear (96).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (21).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (53).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (44).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (9).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (76).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Normal_clear (14).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/clear/Diabetic_clear (52).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (75).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (64).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (74).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (86).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (75).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (98).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (5).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (51).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (101).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (90).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (69).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (92).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (7).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (1).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (104).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (88).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (12).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (101).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (26).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (69).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (34).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (99).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (71).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (6).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (19).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (15).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (6).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (92).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (80).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (50).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (23).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (76).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (102).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (71).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (27).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (84).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (42).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (18).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (27).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (85).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (48).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (1).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (6).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (94).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (32).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (77).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (34).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (50).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (44).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (28).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (30).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (23).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (56).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (45).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (15).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (43).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (35).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (82).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (67).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (24).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (48).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (22).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (51).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (25).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (32).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (38).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (4).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (19).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (58).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (49).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (38).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (44).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (43).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (52).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (80).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (13).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (22).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (87).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (81).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (20).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (60).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (21).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (15).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (9).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (55).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (37).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (46).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (88).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (74).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (95).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (32).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (78).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (97).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (33).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (65).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (21).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (70).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (73).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (68).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (76).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (7).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (60).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (52).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (50).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (104).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (13).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (107).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (3).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (49).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (96).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (81).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (93).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (30).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (53).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (46).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (17).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (21).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (35).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (78).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (18).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (22).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (96).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (100).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (60).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (89).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (29).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (5).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (27).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (84).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (29).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (105).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (18).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (71).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (34).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (79).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (1).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (8).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (86).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (36).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (52).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (68).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (10).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (48).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (14).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (47).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (25).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (62).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (78).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (33).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (75).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (53).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (19).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (109).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (73).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (54).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (93).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (108).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (29).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (67).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (36).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (5).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (40).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (55).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (23).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (59).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (79).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (35).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (55).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (79).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (62).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (106).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (107).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (36).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (16).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (66).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (91).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (81).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (77).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (102).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (57).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (64).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (97).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (66).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (59).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (11).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (57).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (89).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (4).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (11).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (88).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (12).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (39).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (3).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (11).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (14).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (86).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (9).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (70).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (39).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (44).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (82).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (9).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (83).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (87).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (56).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (2).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (37).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (49).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (8).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (72).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (20).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (103).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (62).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (25).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (45).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (84).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (72).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (37).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (94).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (63).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (2).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (46).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (38).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (58).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (31).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (8).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (54).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (80).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (42).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (61).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (67).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (87).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (56).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (10).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (85).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (58).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (72).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (65).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (98).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (82).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (13).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (16).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (59).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (83).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (47).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (83).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (57).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (45).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (30).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (33).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (24).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (31).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (20).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (43).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (41).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (16).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (40).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (69).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (99).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (10).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (61).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (24).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (31).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (28).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (91).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (3).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (17).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (26).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (66).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (17).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (47).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (77).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (100).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (74).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (63).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (26).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (12).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (7).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (64).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (2).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (90).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (105).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (68).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (76).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (103).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (42).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (14).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (40).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (63).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (73).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Myopia_marked (85).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (41).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (4).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (65).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (95).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Normal_marked (28).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (51).jpg
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/marked/Diabetic_marked (61).jpg
# ...
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (91)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (18)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (70)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (89)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (52)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (34)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (92)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (51)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (23)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (59)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (104)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (99)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (87)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (46)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (65)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (30)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (86)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (32)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (55)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (54)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (10)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (33)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (27)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (10)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (81)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (86)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (71)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (1)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (52)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (63)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (10)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (79)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (11)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (3)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (85)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (80)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (47)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (42)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (39)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (20)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (102)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (48)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (7)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (37)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (31)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (24)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (13)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (7)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (104)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (3)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (44)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (100)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (89)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (31)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (48)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (34)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (86)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (78)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (29)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (25)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (53)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (77)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (22)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (71)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (102)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (57)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (97)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (60)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (5)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (98)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (41)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (8)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (96)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (20)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (28)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (38)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (40)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (50)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (84)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (5)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (38)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (56)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (67)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (73)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (30)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (44)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (26)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (6)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (15)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (35)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (76)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (107)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (24)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (43)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (85)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (83)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (24)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (63)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (77)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (39)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (35)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (54)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (107)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (88)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (19)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (11)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (28)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (76)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (51)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (35)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (4)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (23)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (48)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (20)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (70)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (46)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (95)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (2)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (70)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (32)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (82)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (83)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (7)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (2)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (88)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (103)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (49)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (64)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (83)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (39)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (79)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (44)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (67)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (47)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (16)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (52)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (23)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (14)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (84)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (55)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (6)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (45)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (62)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (36)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (73)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (90)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (50)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (65)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (33)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (90)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (9)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (103)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (6)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (81)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (29)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (17)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (77)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (1)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (14)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (27)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (92)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (21)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (12)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (108)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (25)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (47)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (66)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (53)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (71)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (60)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (37)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (66)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (58)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (9)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (36)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (75)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (8)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (27)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (100)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (54)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (82)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (57)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (67)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (53)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (17)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (88)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (62)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (33)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (12)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (87)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (59)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (51)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (22)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (31)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (64)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (61)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (17)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (95)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (93)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Normal (21)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (63)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (94)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (2)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (42)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Diabetic (56)_mask.png
# /kaggle/input/faz-preprocessing/FAZ_preprocessing/masks/Myopia (34)_mask.png

# %%
import os
import cv2 
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
INPUT_IMAGE_PATH='/kaggle/input/faz-preprocessing/FAZ_preprocessing/clear'
INPUT_MASK_PATH='/kaggle/input/faz-preprocessing/FAZ_preprocessing/masks'
OUTPUT_IMAGE_PATH='/kaggle/working/preprocessed_images'
OUTPUT_MASK_PATH='/kaggle/working/preprocessed_masks'

# %%
os.makedirs(OUTPUT_IMAGE_PATH, exist_ok=True)
os.makedirs(OUTPUT_MASK_PATH, exist_ok=True)

# %%
clahe=cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))

# %%
def crop_center(img, cropx=400, cropy=400):
    y,x =img.shape[:2]
    startx=x//2-cropx//2
    starty=y//2-cropy//2
    return img[starty:starty+cropy, startx:startx+cropx]

# %%
def preprocess_image(image_path):
    img=cv2.imread(image_path)
    if img is None:
        print(f"Image not loaded:{image_path}")
        return None

    
    #resize
    img=cv2.resize(img,(512,512))
    
    #crop around center(fovea)
    img=crop_center(img, 400,400)
    
    #CLAHE
    gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    clahe_img=clahe.apply(gray)

    #convert back to 3 channels
    img_clahe=cv2.cvtColor(clahe_img, cv2.COLOR_GRAY2BGR)
    #denoise
    img_denoised=cv2.GaussianBlur(img_clahe,(3,3),0)

    #Normalize (0 to 1)
    img_norm=img_denoised.astype(np.float32)/255.0
    return img_norm

# %%
def preprocess_mask(mask_path):
    mask=cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    if mask is None:
        print(f" Could not read mask: {mask_path}")
        return None
    mask=cv2.resize(mask, (512,512))
    
    mask=crop_center(mask, 400,400)
    
    _, mask = cv2.threshold(mask, 127, 255, cv2.THRESH_BINARY)
    
    return mask

# %%
image_files=sorted(os.listdir(INPUT_IMAGE_PATH))
mask_files=sorted(os.listdir(INPUT_MASK_PATH))

# %%
from tqdm import tqdm

for image_file, mask_file in tqdm(zip(image_files, mask_files), total=len(image_files)):
    
    image_path = os.path.join(INPUT_IMAGE_PATH, image_file)
    mask_path = os.path.join(INPUT_MASK_PATH, mask_file)
    
    img_processed = preprocess_image(image_path)
    mask_processed = preprocess_mask(mask_path)
    
    if img_processed is None or mask_processed is None:
        print(f" Skipping: {image_file}, {mask_file}")
        continue
    
    
    img_save = (img_processed * 255).astype(np.uint8)
    save_img_path = os.path.join(OUTPUT_IMAGE_PATH, image_file)
    cv2.imwrite(save_img_path, img_save)

    
    save_mask_path = os.path.join(OUTPUT_MASK_PATH, mask_file)
    cv2.imwrite(save_mask_path, mask_processed)

print("\n Preprocessing complete! Saved to:")
print(f"Images: {OUTPUT_IMAGE_PATH}")
print(f"Masks:  {OUTPUT_MASK_PATH}")
# Out:
# 100%|██████████| 304/304 [00:08<00:00, 34.99it/s]
#  Preprocessing complete! Saved to:
# Images: /kaggle/working/preprocessed_images
# Masks:  /kaggle/working/preprocessed_masks

# %%
import shutil
shutil.make_archive('/kaggle/working/pre-processed_images', 'zip', '/kaggle/working/preprocessed_images')
shutil.make_archive('/kaggle/working/pre-processed_masks', 'zip', '/kaggle/working/preprocessed_masks')
# Out:
# '/kaggle/working/pre-processed_masks.zip'
